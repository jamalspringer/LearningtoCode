# %%
#!pip install yahoo-finance
import yahoo_finance as YP
from datetime import datetime as dt
import time

# %%
yahoo = YP.Share('aapl')
currentnt_price = yahoo.get_price()
print ("Current AAPL price is %s " % currentnt_price)


def price_getter(ticker, refresh_rate):
    symbol = YP.Share(ticker)
    print symbol.get_price()
    time.sleep(refresh_rate)
    print symbol.get_price()
    
price_getter("aapl", 5)
    

    

symbol = YP.Share("AAPL")
print symbol.get_historical('2017-09-17', '2017-09-18')

# %%
#!pip install quandl
import quandl
import matplotlib as plt
import pandas as pd
import numpy as np

quandl.ApiConfig.api_key = 'wwPmPU7T7UGsprxJge8A'
#quandl.ApiConfig.api_version = '2015-04-09'

# %%
# Out:
#      m_ticker ticker  comp_name comp_name_2 exchange currency_code  \
# None
# 0        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 1        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 2        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 3        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 4        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 5        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 6        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 7        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 8        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 9        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 10       AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 11       AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 12       AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# ...

# %%
#help(quandl.Datatable)
ticker = "NSE/OIL"
price_table = quandl.get(ticker)
print price_table.between_time
# Out:
# <bound method DataFrame.between_time of                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2009-09-30  1096.00  1156.70  1090.00  1135.00  1141.20            19748012.0
# 2009-10-01  1102.00  1173.70  1102.00  1167.00  1166.35             3074254.0
# 2009-10-05  1152.00  1165.90  1136.60  1143.00  1140.55              919832.0
# 2009-10-06  1149.80  1157.20  1132.10  1143.30  1144.90              627957.0
# 2009-10-07  1153.80  1160.70  1140.00  1141.45  1141.60              698216.0
# 2009-10-08  1145.00  1179.80  1142.00  1178.10  1170.20              788173.0
# 2009-10-09  1176.00  1210.00  1165.00  1183.00  1195.65             1047417.0
# 2009-10-12  1184.00  1210.00  1176.00  1193.00  1195.70              464697.0
# 2009-10-14  1198.00  1227.75  1185.00  1192.50  1190.45              581221.0
# 2009-10-15  1198.00  1204.90  1180.05  1184.90  1184.55              301790.0
# ...

# %%
ticker = "NSE/OIL"
price_table = quandl.get(ticker)
#print type(price_table.between_time "05:00"))
price_table.plot.bar()

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot.scatter(x='a', y='b');

ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');

df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

df.plot.scatter(x='a', y='b', c='c', s=50);

print df
# Out:
#            a         b         c         d
# 0   0.890595  0.187085  0.358594  0.517451
# 1   0.187837  0.834384  0.549161  0.374177
# 2   0.894765  0.362857  0.263329  0.227332
# 3   0.220522  0.259915  0.865250  0.895411
# 4   0.767910  0.953968  0.325719  0.519234
# 5   0.189569  0.084438  0.901509  0.075156
# 6   0.459837  0.040946  0.599088  0.485739
# 7   0.604130  0.931666  0.354383  0.397227
# 8   0.470028  0.891474  0.795975  0.839215
# 9   0.294246  0.071254  0.619545  0.358924
# 10  0.926173  0.211165  0.491875  0.272214
# 11  0.833720  0.942478  0.298195  0.427817
# 12  0.121125  0.559526  0.252177  0.203022
# 13  0.828336  0.618281  0.002667  0.480366
# 14  0.656112  0.615567  0.022059  0.786132
# 15  0.272198  0.565870  0.568959  0.464943
# 16  0.934937  0.700388  0.816206  0.306764
# 17  0.891072  0.857339  0.375307  0.340195
# 18  0.632745  0.116633  0.119288  0.279035
# 19  0.606774  0.580941  0.854164  0.183822
# 20  0.083925  0.220352  0.436715  0.941203
# ...
